# %%
# Let's use titanic again.. for fun
# your note book probably looks blank. That's not an error.

# %%
import os 
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
path = "../data/titanic.csv"

titanic = pd.read_csv(path)
# to take a peek at the data
# .head() returns the first 5 rows of the dataframe
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       3         1            Baclini, Mrs. Solomon (Latifa Qurban)  female
# 1       1         0                       Ryerson, Mr. Arthur Larned    male
# 2       1         1  Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female
# 3       1         0                       Newell, Mr. Arthur Webster    male
# 4       1         1                     Spedden, Mr.. Robert Douglas    male
#
#     age  sibsp  parch    ticket      fare            cabin embarked boat  \
# 0  24.0      0      3      2666   19.2583              NaN        C    C
# 1  61.0      1      3  PC 17608  262.3750  B57 B59 B63 B66        C  NaN
# 2  48.0      1      3  PC 17608  262.3750  B57 B59 B63 B66        C    4
# 3  58.0      0      2     35273  113.2750              D48        C  NaN
# 4   6.0      0      2     16966  134.5000              E34        C    3
#
#     body                        home.dest
# 0    NaN               Syria New York, NY
# 1    NaN  Haverford, PA / Cooperstown, NY
# 2    NaN  Haverford, PA / Cooperstown, NY
# 3  122.0                    Lexington, MA
# 4    NaN                  Tuxedo Park, NY

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
def missing_table(newtable):
    print("Missing records in titanic")
    print(pd.isnull(titanic).sum())
    print(" ")

# %%
missing_table(titanic)
# Out:
# Missing records in titanic
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
titanic.drop(['name', 'sibsp', 'parch', 'ticket', 'cabin', 'boat', 'body', 'home.dest'], axis=1, inplace = True)

# %%
titanic.head()
# Out:
#    pclass  survived     sex   age      fare embarked
# 0       3         1  female  24.0   19.2583        C
# 1       1         0    male  61.0  262.3750        C
# 2       1         1  female  48.0  262.3750        C
# 3       1         0    male  58.0  113.2750        C
# 4       1         1    male   6.0  134.5000        C

# %%
titanic.columns
# Out:
# Index(['pclass', 'survived', 'sex', 'age', 'fare', 'embarked'], dtype='object')

# %%
X = titanic.loc[:, titanic.columns != 'survived']
y = titanic['survived']

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   survived  1309 non-null   int64
#  2   sex       1309 non-null   object
#  3   age       1046 non-null   float64
#  4   fare      1308 non-null   float64
#  5   embarked  1307 non-null   object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 61.5+ KB

# %%
# Column transformers

#numeric_features = [
 #'pclass',
 #'age',
 #'fare'
 #]

numeric_features = X.select_dtypes(include=[np.number]).columns

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median'))    
    ])
numeric_features
# Out:
# Index(['pclass', 'age', 'fare'], dtype='object')

# %%
#categorical_features = [
#    'sex',
#    'embarked']

categorical_features = X.select_dtypes(exclude=[np.number]).columns

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
    ])
categorical_features
# Out:
# Index(['sex', 'embarked'], dtype='object')

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %%
#Steps 1,2,3
lo_clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', LogisticRegression(solver = 'liblinear'))])

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state= 1955, test_size=0.3)

#Step 4
lo_clf.fit(X_train, y_train)

#Step 5
y_model_lo = lo_clf.predict(X_test)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
report = classification_report(y_test, y_model_lo)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.84       236
#            1       0.77      0.76      0.76       157
#
#     accuracy                           0.81       393
#    macro avg       0.80      0.80      0.80       393
# weighted avg       0.81      0.81      0.81       393

# %%
accuracy_score(y_test, y_model_lo)
# Out:
# 0.811704834605598

# %%
conf = confusion_matrix(y_test, y_model_lo)

# %%
plt.title('how right or wrong is our model?')
sns.heatmap(conf, annot=True, fmt='d', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
sns.countplot(x='sex', hue='survived', data= titanic)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.pairplot(titanic, hue='survived')

# %%
plt.figure(figsize=(10,10))
titanic_corr = titanic.corr()
sns.heatmap(titanic_corr, annot=True)
plt.show()
