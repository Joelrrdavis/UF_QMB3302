# %% [markdown]
# # Week 2 Optional Workbook

# %% [markdown]
# Welcome to your first optional workbook!
#
# Many of these questions will appear *exactly* the same on the week 2 Quiz, so be sure to answer them to the best of your ability. Note that in future weeks the questions are not identical in some cases, but are very, very close.
#
# This workbook is not submitted. Students are free to use this workbook as a guide on the quiz, that is what it is here for!

# %% [markdown]
# ## Loops

# %% [markdown]
# This section of the assignment will cover `if` statements, `else` statements, `for` loops, and `while` loops.

# %% [markdown]
# ### Comparisons

# %% [markdown]
# #### Question 1
#
# Which of the following operators represent proper means of comparison? **Bold** the correct answers.

# %% [markdown]
# | Answer Choices |
# | --- |
# | a. ==  |
# | b. =< |
# | c. =! |
# | d. > |
# | e. >= |
# | f. < |
# | g. <= |
# | h. != |
# | i. => |

# %% [markdown]
# #### Question 2
#
# Match the following operators with their respective description:
#
# |  ==  |  =<  |  =!  |  >  |  >=  |  <  |  <=  |  !=  |  =>  |
#
# **Note**: Not all answers choices will be used.

# %% [markdown]
# | Descriptor | Answer |
# | --- | --- |
# | Greather than or Equal to | **Answer Here** |
# | Less than | **Answer Here** |
# | Not equal to | **Answer Here** |
# | Greater than | **Answer Here** |
# | Equal to | **Answer Here** |
# | Less than or Equal to | **Answer Here** |

# %% [markdown]
# #### Question 3
#
# All operators produce an `int` output. Place an **X** in the box of the correct answer.

# %% [markdown]
# - [ ] True
# - [ ] False

# %% [markdown]
# ## `if` Statements

# %% [markdown]
# #### Question 4
#
# Suppose you wanted to drive down to Tampa to watch the Rays play baseball, but you would only go if the cheapest ticket cost less than 20 dollars. If so, then your function would output *Take me out to the ballgame!* Tickets cost 26 dollars. Which function best illustrates this statement? Place an **X** in the box of the correct answer.

# %% [markdown]
# - [ ] ![QMB3302 Quiz 2.4.1.png](attachment:c4b85cfc-0578-47cf-8b75-638f7117a3cd.png)

# %% [markdown]
# - [ ] ![QMB3302 Quiz 2.4.2.png](attachment:5d1f7f0a-7af3-418c-b90b-6c47eac77566.png)

# %% [markdown]
# - [ ] ![QMB3302 Quiz 2.4.3.png](attachment:dd3e92c9-6b77-4ac3-97ed-83eeef6c6d9f.png)

# %% [markdown]
# - [ ] ![QMB3302 Quiz 2.4.4.png](attachment:06d06eb2-3ba9-45d8-bd67-1140c49f7b51.png)

# %% [markdown]
# - [ ] None of the answers are true

# %% [markdown]
# #### Question 5
#
# Uh oh... you can't figure out whether you're accelerating, decelerating, or staying at a constant velocity. Your acceleration rate is -0.4 m/s². Which `if` statement correctly makes this determination? Place an **X** in the box of the correct answer.

# %% [markdown]
# - [ ] ![QMB3302 Quiz 2.5.1.png](attachment:dd016c79-f93d-459a-b39b-4bcae1584a4d.png)

# %% [markdown]
# - [ ] ![QMB3302 Quiz 2.5.2.png](attachment:fb120538-b40a-4546-abca-326689fe111b.png)

# %% [markdown]
# - [ ] ![QMB3302 Quiz 2.5.3.png](attachment:f4ef65ad-9588-460b-a450-38fa6db58c96.png)

# %% [markdown]
# - [ ] ![QMB3302 Quiz 2.5.4.png](attachment:735b40e9-9d2d-464d-8c00-0b407b08e21b.png)

# %% [markdown]
# - [ ] None of the answers are true

# %% [markdown]
# #### Question 6
#
# When nesting `if` statements, how many spaces do you need to ensure proper indentation? Please type in the number of spaces you need below.

# %% [markdown]
# **Answer**:

# %% [markdown]
# #### Question 7
#
# Assuming this is a complete code chunk, why is the below code incorrect?
#
# ![QMB3302 Quiz 2.7.1.png](attachment:e0ebc028-9787-428c-92a4-f395e29bb92f.png)

# %% [markdown]
# - [ ] Tom Brady is not the Greatest of All Time (G.O.A.T.)
# - [ ] The variables are not defined
# - [ ] **==** is not a proper operator between two variables
# - [ ] More than one of the answers is correct
# - [ ] You're wrong, this code is actually correct

# %% [markdown]
# #### Question 8
#
# Let's turn this quote into code using an `if` statement:
#
# > Remember...there are no points for second place

# %%
place = 2
if [CodeHere1][CodeHere2] 2:
    [CodeHere3] = 0
    print(points)

# %% [markdown]
# |  Placeholder  |  Answer Choices  |  Answer  |
# | --- | --- | --- |
# |  CodeHere1  |  Places, Points, place, point  |  **Answer Here**  |
# |  CodeHere2  |  =!, !=, ==, =  |  **Answer Here**  |
# |  CodeHere3  |  Place, Point, places, points  |  **Answer Here**  |

# %% [markdown]
# #### Question 9
#
# Steve Jobs wrote some Python code to determine if Apple met its quota for the Apple Newton. What does his code output? Place an **X** in the box of the correct answer.
#
# ![QMB3302 Quiz 2.9.1.png](attachment:ade4c9d0-c175-4735-811c-51bcba5d1f1b.png)

# %% [markdown]
# - [ ] ![QMB3302 Quiz 2.9.2.png](attachment:d3e47f31-7c99-4054-acaf-77e68ae8c6d2.png)

# %% [markdown]
# - [ ] ![QMB3302 Quiz 2.9.3.png](attachment:6fcbbb32-0501-4e25-ba85-e089345b9491.png)

# %% [markdown]
# - [ ] ![QMB3302 Quiz 2.9.4.png](attachment:17371079-288b-49a8-ad1f-6a715e9248fa.png)

# %% [markdown]
# - [ ] ![QMB3302 Quiz 2.9.5.png](attachment:1f937c14-a48c-4fe7-8fd9-3bb9b95c43b5.png)

# %% [markdown]
# - [ ] ![QMB3302 Quiz 2.9.6.png](attachment:4f9aa426-bf21-4a24-ba4b-542f3745516f.png)

# %% [markdown]
# ## Nesting `if` Statements

# %% [markdown]
# #### Question 10
#
# What type of error will you receive of you forget to indent your nested *if* statement? Place an **X** in the box of the correct answer.
#
#
# - [ ] SyntaxError
# - [ ] SpacingError
# - [ ] RuntimeError
# - [ ] IndexError
# - [ ] IndentationError

# %% [markdown]
# #### Question 11
#
# Will the following nested `if` statement run? If not, why? Place an **X** in the box of the correct answer.
#
#
# ![QMB3302 Quiz 2.11.1.png](attachment:0ab6fa3d-ae22-48df-9375-332459c44763.png)
#
# - [ ] Yes, it will run with no problems
# - [ ] Nope, -0 is not a properly formatted `int` variable
# - [ ] Nah, there is a `RuntimeError` due to missing punctuation
# - [ ] Negative, Ghost Rider, there is a `SyntaxError`
# - [ ] No, it won't run, but for another reason

# %% [markdown]
# ## `else` Statements

# %% [markdown]
# #### Question 12
#
# What is the purpose of an `else` statement? Choose the *best* answer. Place an **X** in the box of the correct answer.
#
#
# - [ ] It serves as a catchall function if `if` statement conditions are not met
# - [ ] It states a condition that must be met for the code to be run
# - [ ] It allows the code to be run continuously while a condition is true
# - [ ] It allows a function to escape a continuous loop
# - [ ] None of these answers are correct

# %% [markdown]
# #### Question 13
#
# What is the output of the following code?
#
# ![QMB3302 Quiz 2.13.1.png](attachment:575dc7eb-46c3-428a-811d-64ce171d5554.png)
#
# - [ ] There will be an `intError` since -0 is not a proprly formatted integer
# - [ ] 0 or more
# - [ ] less than 0
# - [ ] There will be no output
# - [ ] None of these answers are correct

# %% [markdown]
# ## `while` Loops

# %% [markdown]
# #### Question 14
#
# How many outputs will this following code have? Place an **X** in the box of the correct answer.
#
# ![QMB3302 Quiz 2.14.1.png](attachment:78dbb1c0-fc43-45f4-9e81-68336239931d.png)
#
# - [ ] 10
# - [ ] There are an infinite number of mosquitoes
# - [ ] 5
# - [ ] Mosquitoes don't exist in Florida (0)
# - [ ] None of these answer are correct

# %% [markdown]
# #### Question 15
#
# Suppose you wanted to write code to escape an otherwise infinitely repeating function. How would you do that? Place an **X** in the box of the correct answer.
#
# - [ ] Stop the kernal
# - [ ] Embed the rest of the function in another loop within the loop
# - [ ] Write an `esc` function to escape the loop
# - [ ] Utilize the `break` function within your loop
# - [ ] None of these answers are correct

# %% [markdown]
# #### Question 16
#
# A `while` loop is most closely related to which other type of function. Place an **X** in the box of the correct answer.
#
# - [ ] `when` Statement
# - [ ] `if` Statement
# - [ ] `for` Loop
# - [ ] `else` Statement
# - [ ] None of these answers are correct

# %% [markdown]
# ## `for` Loops

# %% [markdown]
# #### Question 17
#
# Identify the parts of a `for` loop below:

# %%
for x in y
    z

# %% [markdown]
# |  Placeholder  |  Answer Choices  |  Answer  |
# | --- | --- | --- |
# |  x  |  Repeating variable, Iteration variable, Placeholder variable, None of these answers are correct  |  **Answer Here**  |
# |  y  |  Repeaters, Iterables, Placeholdings, None of these answers are correct  |  **Answer Here**  |
# |  z  |  Statement, Print variable, Iterable, None of these answers are correct  |  **Answer Here**  |

# %% [markdown]
# #### Question 18
#
# Within a `for` loop, which *line* of code would you use to increase the number within a variable? Place an **X** in the box of the correct answer.
#
# - [ ] `add(count, 1)`
# - [ ] `+ 1 count`
# - [ ] `count + 1`
# - [ ] `number = count + 1`
# - [ ] None of these answers are correct

# %% [markdown]
# #### Question 19
#
# Coach Napier is trying to count his total wins for the 2022 season. Which `for` function will help him do so and produce the following output:
#
# ![QMB3302 Quiz 2.19.1.png](attachment:49012463-7917-4dac-99c4-5dd2336cc710.png)
#
# Place an **X** in the box of the correct answer.
#
# - [ ] ![QMB3302 Quiz 2.19.2.png](attachment:c741a9e2-5b4c-433d-8801-251b6c0d39f6.png)
# - [ ] ![QMB3302 Quiz 2.19.3.png](attachment:3d8bf910-14b7-4571-9988-81699509f3d4.png)
# - [ ] ![QMB3302 Quiz 2.19.4.png](attachment:285cf772-b53a-4718-b426-18ae3aab0034.png)
# - [ ] ![QMB3302 Quiz 2.19.5.png](attachment:4aed88d3-727b-407a-9850-df6c3a9bc3ce.png)
# - [ ] None of these answers are correct

# %% [markdown]
# # Functions

# %% [markdown]
# This section of the assignment will cover the basics of functions and user-defined functions.

# %% [markdown]
# #### Question 20
#
# University of Florida President Sasse wanted to *define* a function to count the student enrollment of the top three colleges: Liberal Arts, Engineering, and Business. His code looks like this:

# %%
college_count = (liberal_arts, engineering, business)
    enrollment = liberal_arts + engineering + business
    enrollment

# %% [markdown]
# What is he missing from his code? Place an **X** in the box of the correct answer.
#
# - [ ] `return` and `def`
# - [ ] `for` and `in`
# - [ ] `def` and `for`
# - [ ] `for` and `return`
# - [ ] None of these answers are correct
