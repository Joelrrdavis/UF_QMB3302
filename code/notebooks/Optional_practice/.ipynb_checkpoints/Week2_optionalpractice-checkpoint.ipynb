# %%
### Optional Practice Workbook: Control Structures and Functions

# Introduction
# This workbook is designed to help you practice the concepts of `for` loops and functions.
# The goal is to reinforce your understanding by experimenting with code and solving small challenges.

# Let's get started!

# Section 1: Exploring `for` Loops

## Exercise 1: Iterate Over a String
# Write a `for` loop to iterate through each character in the string "Python" and print it.

word = "Python"
# Your code here

## Exercise 2: Iterate Over a List
# Write a `for` loop to iterate through the list `[10, 20, 30, 40, 50]` and print each number doubled.

numbers = [10, 20, 30, 40, 50]
# Your code here

## Exercise 3: Create a Range
# Use a `for` loop with the `range()` function to print numbers from 1 to 10.

# Your code here

## Exercise 4: Nested Loops
# Write a nested `for` loop to print a multiplication table (from 1x1 to 5x5).

# Your code here


# Section 2: Practical Applications of `for` Loops

## Exercise 5: Count Occurrences
# Write a `for` loop to count how many times the letter 'a' appears in the string "banana".

fruit = "banana"
# Your code here

## Exercise 6: Summing Numbers
# Write a `for` loop to calculate the sum of the numbers in the list `[4, 7, 1, 9, 3]`.

nums = [4, 7, 1, 9, 3]
# Your code here

## Exercise 7: Find the Maximum
# Write a `for` loop to find the largest number in the list `[5, 17, 2, 8, 12]`.

values = [5, 17, 2, 8, 12]
# Your code here


# Section 3: Practicing Functions

## Exercise 8: Create a Greeting Function
# Define a function called `greet` that takes a name as input and prints "Hello, [name]!".

# Your code here

## Exercise 9: Sum of a List Function
# Define a function called `sum_list` that takes a list of numbers as input and returns their sum.

# Your code here

## Exercise 10: Find the Average
# Define a function called `average` that takes a list of numbers as input and returns the average.

# Your code here


# Section 4: Putting It All Together

## Exercise 11: Combine Loops and Functions
# Write a function called `count_vowels` that takes a string as input and returns the number of vowels in it.

# Your code here

## Exercise 12: Nested Loops with Functions
# Write a function called `multiplication_table` that takes a number `n` as input and prints an `n x n` multiplication table.

# Your code here


# Section 5: Explore and Experiment

## Challenge 1: Prime Numbers
# Write a function called `is_prime` that takes a number as input and returns `True` if it is a prime number, and `False` otherwise.

# Your code here

## Challenge 2: Fibonacci Sequence
# Write a function called `fibonacci` that takes a number `n` as input and prints the first `n` numbers in the Fibonacci sequence.

# Your code here


# Great work completing this workbook! Feel free to experiment with the exercises and modify them to explore further.
