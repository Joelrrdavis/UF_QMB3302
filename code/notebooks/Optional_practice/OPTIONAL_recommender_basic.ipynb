# %%
#super basic recommender example
# if you run this, you may want to use google colab (see last week)
# the package I use here is old, and not used in practice. But it is very simple, so 
# a good way to get started.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#data from 
#https://github.com/zygmuntz/goodbooks-10k

# %%
#import from a file (not loaded in canvas)
books = pd.read_csv('../data/books.csv')
ratings = pd.read_csv('../data/ratings.csv')

# %%
books.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                      authors  original_publication_year  \
# 0  9.780439e+12              Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPré                     1997.0
# 2  9.780316e+12              Stephenie Meyer                     2005.0
# 3  9.780061e+12                   Harper Lee                     1960.0
# 4  9.780743e+12          F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... ratings_count  \
# ...

# %%
ratings.head(10)
# Out:
#    user_id  book_id  rating
# 0        1      258       5
# 1        2     4081       4
# 2        2      260       5
# 3        2     9296       5
# 4        2     2318       3
# 5        2       26       4
# 6        2      315       3
# 7        2       33       4
# 8        2      301       5
# 9        2     2686       5

# %%
books.describe()
# Out:
#            book_id  goodreads_book_id  best_book_id       work_id  \
# count  10000.00000       1.000000e+04  1.000000e+04  1.000000e+04
# mean    5000.50000       5.264697e+06  5.471214e+06  8.646183e+06
# std     2886.89568       7.575462e+06  7.827330e+06  1.175106e+07
# min        1.00000       1.000000e+00  1.000000e+00  8.700000e+01
# 25%     2500.75000       4.627575e+04  4.791175e+04  1.008841e+06
# 50%     5000.50000       3.949655e+05  4.251235e+05  2.719524e+06
# 75%     7500.25000       9.382225e+06  9.636112e+06  1.451775e+07
# max    10000.00000       3.328864e+07  3.553423e+07  5.639960e+07
#
#         books_count        isbn13  original_publication_year  average_rating  \
# count  10000.000000  9.415000e+03                9979.000000    10000.000000
# mean      75.712700  9.755044e+12                1981.987674        4.002191
# std      170.470728  4.428619e+11                 152.576665        0.254427
# ...

# %%
ratings.describe()
# Out:
#             user_id       book_id        rating
# count  5.976479e+06  5.976479e+06  5.976479e+06
# mean   2.622446e+04  2.006477e+03  3.919866e+00
# std    1.541323e+04  2.468499e+03  9.910868e-01
# min    1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.281300e+04  1.980000e+02  3.000000e+00
# 50%    2.593800e+04  8.850000e+02  4.000000e+00
# 75%    3.950900e+04  2.973000e+03  5.000000e+00
# max    5.342400e+04  1.000000e+04  5.000000e+00

# %%
from surprise import Dataset
from surprise import Reader

# %%
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(ratings[['user_id', 'book_id', 'rating']], reader)

# %%
from surprise import SVD
from surprise.model_selection import cross_validate
svd = SVD(verbose=True, n_epochs=10)
cross_validate(svd, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Evaluating RMSE, MAE of algorithm SVD on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.8516  0.8528  0.8532  0.8525  0.0007
# MAE (testset)     0.6654  0.6657  0.6659  0.6657  0.0002
# Fit time          13.60   15.09   15.19   14.63   0.73
# Test time         11.39   9.72    10.26   10.46   0.69
# ...

# %%
svd

# %%
svd.head()

# %%
#trainset = data.build_full_trainset()
#svd.fit(trainset)

# %%
svd.predict(uid=1, iid=10)
#Prediction(uid=10, iid=100, r_ui=None, est=4.051206489275292, details={'was_impossible': False})
# Out:
# Prediction(uid=1, iid=10, r_ui=None, est=3.840590108174465, details={'was_impossible': False})

# %%
svd.predict(uid=1, iid=11)
# Out:
# Prediction(uid=1, iid=11, r_ui=None, est=3.911337202276513, details={'was_impossible': False})

# %%
# The package documentation has an easier suggestion on how to retrieve the top -n recommendations.
# be aware of run times... this will take a long long time on most computers.

# %%
def get_top_n(predictions, n=10):
    """Return the top-N recommendation for each user from a set of predictions.
    Args:
        predictions(list of Prediction objects): The list of predictions, as
            returned by the test method of an algorithm.
        n(int): The number of recommendation to output for each user. Default
            is 10.
    Returns:
    A dict where keys are user (raw) ids and values are lists of tuples:
        [(raw item id, rating estimation), ...] of size n.
    """

    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

# %%
# First train an SVD algorithm on the movielens dataset.
trainset = data.build_full_trainset()
algo = SVD()
algo.fit(trainset)

# %%
# Than predict ratings for all pairs (u, i) that are NOT in the training set.
testset = trainset.build_anti_testset()
predictions = algo.test(testset)

top_n = get_top_n(predictions, n=10)

# %%
# Print the recommended items for each user
for uid, user_ratings in top_n.items():
    print(uid, [iid for (iid, _) in user_ratings])
